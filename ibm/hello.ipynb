# %%
from qiskit import QuantumCircuit
from qiskit_ibm_runtime import QiskitRuntimeService, SamplerV2 as Sampler
 
# Create empty circuit
example_circuit = QuantumCircuit(2)
example_circuit.measure_all()
 
# You'll need to specify the credentials when initializing QiskitRuntimeService, if they were not previously saved.
service = QiskitRuntimeService()
backend = service.least_busy(operational=True, simulator=False)
 
sampler = Sampler(backend)
job = sampler.run([example_circuit])
print(f"job id: {job.job_id()}")
result = job.result()
print(result)
# Out:
# job id: cvgzwgap7drg008m58zg
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 15
#      13 job = sampler.run([example_circuit])
#      14 print(f"job id: {job.job_id()}")
# ---> 15 result = job.result()
#      16 print(result)
#
# File ~/.pyenv/versions/3.12.1/lib/python3.12/site-packages/qiskit_ibm_runtime/runtime_job_v2.py:133, in RuntimeJobV2.result(self, timeout, decoder)
#     118 """Return the results of the job.
#     119
#     120 Args:
#    (...)
#     130     RuntimeInvalidStateError: If the job was cancelled, and attempting to retrieve result.
#     131 """
#     132 _decoder = decoder or self._final_result_decoder
# --> 133 self.wait_for_final_state(timeout=timeout)
#     134 if self._status == "ERROR":
#     135     error_message = self._reason if self._reason else self._error_message
#
# File ~/.pyenv/versions/3.12.1/lib/python3.12/site-packages/qiskit_ibm_runtime/runtime_job_v2.py:253, in RuntimeJobV2.wait_for_final_state(self, timeout)
#     249             raise RuntimeJobTimeoutError(
#     250                 f"Timed out waiting for job to complete after {timeout} secs."
#     251             )
#     252         time.sleep(0.1)
# --> 253         status = self.status()
#     254 except futures.TimeoutError:
#     255     raise RuntimeJobTimeoutError(
#     256         f"Timed out waiting for job to complete after {timeout} secs."
#     257     )
#
# File ~/.pyenv/versions/3.12.1/lib/python3.12/site-packages/qiskit_ibm_runtime/runtime_job_v2.py:170, in RuntimeJobV2.status(self)
#     164 def status(self) -> JobStatus:
#     165     """Return the status of the job.
#     166
#     167     Returns:
#     168         Status of this job.
#     169     """
# --> 170     self._set_status_and_error_message()
#     171     return self._status
#
# File ~/.pyenv/versions/3.12.1/lib/python3.12/site-packages/qiskit_ibm_runtime/base_runtime_job.py:207, in BaseRuntimeJob._set_status_and_error_message(self)
#     205 """Fetch and set status and error message."""
#     206 if self._status not in self.JOB_FINAL_STATES:
# --> 207     response = self._api_client.job_get(job_id=self.job_id())
#     208     self._set_status(response)
#     209     self._set_error_message(response)
#
# File ~/.pyenv/versions/3.12.1/lib/python3.12/site-packages/qiskit_ibm_runtime/api/clients/runtime.py:115, in RuntimeClient.job_get(self, job_id, exclude_params)
#     106 def job_get(self, job_id: str, exclude_params: bool = True) -> Dict:
#     107     """Get job data.
#     108
#     109     Args:
#    (...)
#     113         JSON response.
#     114     """
# --> 115     response = self._api.program_job(job_id).get(exclude_params=exclude_params)
#     116     logger.debug("Runtime job get response: %s", response)
#     117     return response
#
# File ~/.pyenv/versions/3.12.1/lib/python3.12/site-packages/qiskit_ibm_runtime/api/rest/program_job.py:59, in ProgramJob.get(self, exclude_params)
#      57 if exclude_params:
#      58     payload["exclude_params"] = "true"
# ---> 59 return self.session.get(self.get_url("self"), params=payload).json(cls=RuntimeDecoder)
#
# File ~/.pyenv/versions/3.12.1/lib/python3.12/site-packages/requests/sessions.py:602, in Session.get(self, url, **kwargs)
#     594 r"""Sends a GET request. Returns :class:`Response` object.
#     595
#     596 :param url: URL for the new :class:`Request` object.
#     597 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     598 :rtype: requests.Response
#     599 """
#     601 kwargs.setdefault("allow_redirects", True)
# --> 602 return self.request("GET", url, **kwargs)
#
# File ~/.pyenv/versions/3.12.1/lib/python3.12/site-packages/qiskit_ibm_runtime/api/session.py:328, in RetrySession.request(self, method, url, bare, **kwargs)
#     326 try:
#     327     self._log_request_info(final_url, method, kwargs)
# --> 328     response = super().request(method, final_url, headers=headers, **kwargs)
#     329     response.raise_for_status()
#     330 except RequestException as ex:
#     331     # Wrap the requests exceptions into a IBM Q custom one, for
#     332     # compatibility.
#
# File ~/.pyenv/versions/3.12.1/lib/python3.12/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/.pyenv/versions/3.12.1/lib/python3.12/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/.pyenv/versions/3.12.1/lib/python3.12/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File ~/.pyenv/versions/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 response_conn = conn if not release_conn else None
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#     805 clean_exit = True
#
# File ~/.pyenv/versions/3.12.1/lib/python3.12/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/.pyenv/versions/3.12.1/lib/python3.12/site-packages/urllib3/connection.py:464, in HTTPConnection.getresponse(self)
#     461 from .response import HTTPResponse
#     463 # Get the response from http.client.HTTPConnection
# --> 464 httplib_response = super().getresponse()
#     466 try:
#     467     assert_header_parsing(httplib_response.msg)
#
# File ~/.pyenv/versions/3.12.1/lib/python3.12/http/client.py:1419, in HTTPConnection.getresponse(self)
#    1417 try:
#    1418     try:
# -> 1419         response.begin()
#    1420     except ConnectionError:
#    1421         self.close()
#
# File ~/.pyenv/versions/3.12.1/lib/python3.12/http/client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File ~/.pyenv/versions/3.12.1/lib/python3.12/http/client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File ~/.pyenv/versions/3.12.1/lib/python3.12/socket.py:707, in SocketIO.readinto(self, b)
#     705 while True:
#     706     try:
# --> 707         return self._sock.recv_into(b)
#     708     except timeout:
#     709         self._timeout_occurred = True
#
# File ~/.pyenv/versions/3.12.1/lib/python3.12/ssl.py:1253, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1249     if flags != 0:
#    1250         raise ValueError(
#    1251           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1252           self.__class__)
# -> 1253     return self.read(nbytes, buffer)
#    1254 else:
#    1255     return super().recv_into(buffer, nbytes, flags)
#
# File ~/.pyenv/versions/3.12.1/lib/python3.12/ssl.py:1105, in SSLSocket.read(self, len, buffer)
#    1103 try:
#    1104     if buffer is not None:
# -> 1105         return self._sslobj.read(len, buffer)
#    1106     else:
#    1107         return self._sslobj.read(len)
#
# KeyboardInterrupt:
