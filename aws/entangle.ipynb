# %%
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister
import runner

q = QuantumRegister(2, name="quantum")
c = ClassicalRegister(2, name="classical")
qc = QuantumCircuit(q, c)
qc.h(q[0])
qc.cx(q[0], q[1])
qc.measure(q, c)

runner.run(qc)
qc.draw("mpl")
# Out:
# {'11': 53, '00': 47}
